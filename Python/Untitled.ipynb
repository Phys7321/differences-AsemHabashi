# %%
from math import sin

# %%
from myder_modified import centraldiff, second_der
# Out:
# Traceback (most recent call last):
#
#   File "/home/Asem/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-3-854607ca10c2>", line 1, in <module>
#     from myder_modified import centraldiff, second_der
#
#   File "/home/Asem/Desktop/computational_physics_course/differences-AsemHabashi/Python/myder_modified.py", line 70
#     c.append(scnd_der)
#     ^
# SyntaxError: invalid syntax

# %%
from myder_modified import centraldiff, second_der
# Out:
# Traceback (most recent call last):
#
#   File "/home/Asem/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-4-854607ca10c2>", line 1, in <module>
#     from myder_modified import centraldiff, second_der
#
#   File "/home/Asem/Desktop/computational_physics_course/differences-AsemHabashi/Python/myder_modified.py", line 70
#     g.append(scnd_der)
#     ^
# SyntaxError: invalid syntax

# %%
from myder_modified import centraldiff, second_der

# %%
def f(x):
    f=(sin(1/(x*(x-2)))**2)
    return f

# %%
import matplotlib.pyplot as plt

# %%
a=-1
b=3
N=10037
x=[]
y=[]

#def firstder(f,t):
#   f1=(f(t+(k+1/2)*h)-f(t+(k-1/2)*h))/h
#    return f1

for i in range(0,N):
    xi=a+i*(b-a)/N
    yi=f(xi)
    x.append(xi)
    y.append(yi)

y1=centraldiff(f,a,b,N)
y2=second_der(f,a,b,N)


plt.plot(x,y)

# %%
plt.plot(x,y1)

# %%
plt.plot(x,y2)

# %%
plt.plot(x,y1)
plt.axis([0,3,-3,3])
# Out:
# [0, 3, -3, 3]

# %%
plt.plot(x,y2)
plt.axis([0,3,-3,3])
# Out:
# [0, 3, -3, 3]

# %%
plt.plot(x,y1)
plt.axis([0,3,-10,10])
# Out:
# [0, 3, -10, 10]

# %%
plt.plot(x,y2)
plt.axis([0,3,-100,100])
# Out:
# [0, 3, -100, 100]
